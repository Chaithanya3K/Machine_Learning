# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaithanya3K/Machine_Learning/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from sklearn.datasets import load_iris

# %%
iris=load_iris()

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df=pd.DataFrame(iris.data,columns=iris.feature_names)

# %%
df['target']=iris.target

# %%
df0=df[:50]
df1=df[50:100]
df2=df[100:]

# %%
import matplotlib.pyplot as plt
plt.xlable('sepal Length')
plt.ylable('seple width')
plt.scatter(df0['sepal length'],df0['sepal width'],color='green')
plt.scatter(df1['sepal length'],df1['sepal width'],color='red')

# %%
from sklearn.model_selection import train_test_split
x=df.drop(['target'],axis='columns')
y=df.target
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
knn.score(x_test,y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix
y_pred=knn.predict(x_test)
cn=confusion_matrix(y_test,y_pred)
cn
# Out:
# array([[19,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0, 13]])
